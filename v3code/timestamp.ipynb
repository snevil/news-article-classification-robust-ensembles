# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, confusion_matrix


df = pd.read_csv("../data/raw/development.csv")

# %%
df["timestamp"]
# Out:
# 0        2004-09-16 22:39:53
# 1        2004-12-17 19:01:14
# 2        2006-10-05 18:42:29
# 3        0000-00-00 00:00:00
# 4        2006-09-22 17:28:57
#                 ...
# 79992    2008-01-23 11:39:35
# 79993    0000-00-00 00:00:00
# 79994    0000-00-00 00:00:00
# 79995    0000-00-00 00:00:00
# 79996    2007-10-24 17:15:44
# Name: timestamp, Length: 79997, dtype: object
