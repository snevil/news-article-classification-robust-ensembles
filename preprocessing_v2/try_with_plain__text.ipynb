# %%
import pandas as pd
import numpy as np

# Load datasets
df_token = pd.read_csv("../data/processed/development_token_nohref_in_text.csv")
df_raw   = pd.read_csv("../data/raw/development.csv")

# Keep only what serve dal raw
df_raw = df_raw[["Id", "text", "timestamp"]]

# Merge
df = df_token.drop(columns=["text"], errors="ignore").merge(
	df_raw,
	on="Id",
	how="left"
)

print(df.columns)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.11.4' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
